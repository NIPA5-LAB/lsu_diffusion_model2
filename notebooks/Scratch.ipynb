# %% [markdown]
# # Explore notebook

# %% [markdown]
#     A notebook for exploring python, jupyter etc.

# %%
D = 100
d = 50

# %%
D
# Out:
# 100

# %%
whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# D          int     100
# d          int     50

# %%
import numpy as np

# %%
Lx = 8
dx = 0.5 #grid spacing
x = np.arange (start=0, stop=Lx, step=dx) #arrange function
nx = len(x) #how many  bujhay len function ta

# %%
nx
# Out:
# 16

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ,
#        6.5, 7. , 7.5])

# %%
x1 = np.linspace(start=0, stop=Lx, num= Lx//dx, endpoint=True )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x1 = np.linspace(start=0, stop=Lx, num= Lx//dx, endpoint=True )
#
# File /opt/tljh/user/envs/csdms/lib/python3.13/site-packages/numpy/_core/function_base.py:122, in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#      26 @array_function_dispatch(_linspace_dispatcher)
#      27 def linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None,
#      28              axis=0, *, device=None):
#      29     """
#      30     Return evenly spaced numbers over a specified interval.
#      31
#    (...)    120
#     121     """
# --> 122     num = operator.index(num)
#     123     if num < 0:
#     124         raise ValueError(
#     125             f"Number of samples, {num}, must be non-negative."
#     126         )
#
# ...

# %%
x1 = np.linspace(start=0, stop=Lx, num= 7, endpoint=True )

# %%
x1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x1
#
# NameError: name 'x1' is not defined

# %%
x1 = np.linspace(start=0, stop=Lx, num= int(Lx//dx), endpoint=True )

# %%
x1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x1
#
# NameError: name 'x1' is not defined

# %% [markdown]
# Set up the initial conditions for the model.
# The concentration "C" is a step function with a high value on the left,
# a low value on the right,
# and the step at the center of the domain.

# %%
C = np.zeros_like(x)
C_left = 500
C_right = 0
C[x <= Lx//2] =C_left #c for values of x that are less than half the domain size are set to be on left, // is important
C[x > Lx//2] =C_right

# %%
C
